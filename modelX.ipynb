# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datasets

# %%
data = pd.read_csv('bodyfat.csv')

# %%
data.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.4   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
data.shape
# Out:
# (252, 15)

# %%
data.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.151190   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368417   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# std      8.430476   10.783077    7.164058    5.249952    2.411805    1.694893
# min     79.300000   69.400000   85.000000   47.200000   33.000000   19.100000
# 25%     94.350000   84.575000   95.500000   56.000000   36.975000   22.000000
# 50%     99.650000   90.950000   99.300000   59.000000   38.500000   22.800000
# 75%    105.375000   99.325000  103.525000   62.350000   39.925000   24.000000
# max    136.200000  148.100000  147.700000   87.300000   49.100000   33.900000
#
#            Biceps     Forearm       Wrist
# count  252.000000  252.000000  252.000000
# mean    32.273413   28.663889   18.229762
# std      3.021274    2.020691    0.933585
# min     24.800000   21.000000   15.800000
# 25%     30.200000   27.300000   17.600000
# 50%     32.050000   28.700000   18.300000
# 75%     34.325000   30.000000   18.800000
# max     45.000000   34.900000   21.400000

# %%
data.dropna()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.4   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
data.drop_duplicates()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.4   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %% [markdown]
# I'm going to be splitting the dataset into features and labels. The features (X) variable consists of the physical features i'm using to make predictions and the labels variable is what i'm trying to predict (Y). I'm not really good with the iloc() function i think it would've done this easier but regardless, i'm still gonna do it my way

# %%
# Features = Independent variable
# Labels = Dependent variable
features = data[['Density','Weight','Height','Neck','Chest','Abdomen','Hip','Thigh','Knee','Ankle','Biceps','Forearm','Wrist']]
labels = data["BodyFat"]

# %% [markdown]
# Visualizing the Features

# %%
features.head()
# Out:
#    Density  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   1.0708  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   1.0853  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   1.0414  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   1.0751  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   1.0340  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist
# 0    32.0     27.4   17.1
# 1    30.5     28.9   18.2
# 2    28.8     25.2   16.6
# 3    32.4     29.4   18.2
# 4    32.2     27.7   17.7

# %%
features.shape
# Out:
# (252, 13)

# %%
features.describe()
# Out:
#           Density      Weight      Height        Neck       Chest     Abdomen  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574  178.924405   70.148810   37.992063  100.824206   92.555952
# std      0.019031   29.389160    3.662856    2.430913    8.430476   10.783077
# min      0.995000  118.500000   29.500000   31.100000   79.300000   69.400000
# 25%      1.041400  159.000000   68.250000   36.400000   94.350000   84.575000
# 50%      1.054900  176.500000   70.000000   38.000000   99.650000   90.950000
# 75%      1.070400  197.000000   72.250000   39.425000  105.375000   99.325000
# max      1.108900  363.150000   77.750000   51.200000  136.200000  148.100000
#
#               Hip       Thigh        Knee       Ankle      Biceps     Forearm  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    99.904762   59.405952   38.590476   23.102381   32.273413   28.663889
# std      7.164058    5.249952    2.411805    1.694893    3.021274    2.020691
# min     85.000000   47.200000   33.000000   19.100000   24.800000   21.000000
# 25%     95.500000   56.000000   36.975000   22.000000   30.200000   27.300000
# 50%     99.300000   59.000000   38.500000   22.800000   32.050000   28.700000
# 75%    103.525000   62.350000   39.925000   24.000000   34.325000   30.000000
# max    147.700000   87.300000   49.100000   33.900000   45.000000   34.900000
#
#             Wrist
# count  252.000000
# mean    18.229762
# std      0.933585
# min     15.800000
# 25%     17.600000
# 50%     18.300000
# 75%     18.800000
# max     21.400000

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   Weight   252 non-null    float64
#  2   Height   252 non-null    float64
#  3   Neck     252 non-null    float64
#  4   Chest    252 non-null    float64
#  5   Abdomen  252 non-null    float64
#  6   Hip      252 non-null    float64
#  7   Thigh    252 non-null    float64
#  8   Knee     252 non-null    float64
#  9   Ankle    252 non-null    float64
#  10  Biceps   252 non-null    float64
#  11  Forearm  252 non-null    float64
#  12  Wrist    252 non-null    float64
# dtypes: float64(13)
# memory usage: 25.7 KB

# %%
features.dropna()
# Out:
#      Density  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0     1.0708  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1     1.0853  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2     1.0414  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3     1.0751  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4     1.0340  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0
# ..       ...     ...     ...   ...    ...      ...    ...    ...   ...    ...
# 247   1.0736  134.25   67.00  34.9   89.2     83.6   88.8   49.6  34.8   21.5
# 248   1.0236  201.00   69.75  40.9  108.5    105.0  104.5   59.6  40.8   23.2
# 249   1.0328  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 250   1.0399  190.75   70.50  38.9  108.3    101.3   97.8   56.0  41.6   22.7
# 251   1.0271  207.50   70.00  40.8  112.4    108.5  107.1   59.3  42.2   24.6
#
#      Biceps  Forearm  Wrist
# 0      32.0     27.4   17.1
# 1      30.5     28.9   18.2
# 2      28.8     25.2   16.6
# 3      32.4     29.4   18.2
# 4      32.2     27.7   17.7
# ..      ...      ...    ...
# 247    25.6     25.7   18.5
# 248    35.2     28.6   20.1
# 249    31.3     27.2   18.0
# 250    30.5     29.4   19.8
# 251    33.7     30.0   20.9
#
# [252 rows x 13 columns]

# %%
features.drop_duplicates()
# Out:
#      Density  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0     1.0708  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1     1.0853  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2     1.0414  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3     1.0751  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4     1.0340  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0
# ..       ...     ...     ...   ...    ...      ...    ...    ...   ...    ...
# 247   1.0736  134.25   67.00  34.9   89.2     83.6   88.8   49.6  34.8   21.5
# 248   1.0236  201.00   69.75  40.9  108.5    105.0  104.5   59.6  40.8   23.2
# 249   1.0328  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 250   1.0399  190.75   70.50  38.9  108.3    101.3   97.8   56.0  41.6   22.7
# 251   1.0271  207.50   70.00  40.8  112.4    108.5  107.1   59.3  42.2   24.6
#
#      Biceps  Forearm  Wrist
# 0      32.0     27.4   17.1
# 1      30.5     28.9   18.2
# 2      28.8     25.2   16.6
# 3      32.4     29.4   18.2
# 4      32.2     27.7   17.7
# ..      ...      ...    ...
# 247    25.6     25.7   18.5
# 248    35.2     28.6   20.1
# 249    31.3     27.2   18.0
# 250    30.5     29.4   19.8
# 251    33.7     30.0   20.9
#
# [252 rows x 13 columns]

# %%
features.isnull()
# Out:
#      Density  Weight  Height   Neck  Chest  Abdomen    Hip  Thigh   Knee  \
# 0      False   False   False  False  False    False  False  False  False
# 1      False   False   False  False  False    False  False  False  False
# 2      False   False   False  False  False    False  False  False  False
# 3      False   False   False  False  False    False  False  False  False
# 4      False   False   False  False  False    False  False  False  False
# ..       ...     ...     ...    ...    ...      ...    ...    ...    ...
# 247    False   False   False  False  False    False  False  False  False
# 248    False   False   False  False  False    False  False  False  False
# 249    False   False   False  False  False    False  False  False  False
# 250    False   False   False  False  False    False  False  False  False
# 251    False   False   False  False  False    False  False  False  False
#
#      Ankle  Biceps  Forearm  Wrist
# 0    False   False    False  False
# 1    False   False    False  False
# 2    False   False    False  False
# 3    False   False    False  False
# 4    False   False    False  False
# ..     ...     ...      ...    ...
# 247  False   False    False  False
# 248  False   False    False  False
# 249  False   False    False  False
# 250  False   False    False  False
# 251  False   False    False  False
#
# [252 rows x 13 columns]

# %%
sns.histplot(features,kde=False,bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
#represents the correlation of data in the columns using a heatmap
sns.heatmap(features.corr())
# Out:
# <Axes: >

# %%
#plotting the distribution of the numerical features with a histogram
features.hist(figsize=(15, 8), bins=50, xlabelsize=8, ylabelsize=5);

# %% [markdown]
# ## Training Stage

# %%
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
# splitting the data into training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2)

# %%
# feature standardization
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# initializing and training the Linear Regression Algorithm to fit my Model
super_model = LinearRegression()
super_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#displaying training and testing accuracy
print("Training accuracy: {}%".format(round(super_model.score(X_train, y_train), 2)*100))
print("Testing accuracy: {}%".format(round(super_model.score(X_test, y_test), 2)*100))
# Out:
# Training accuracy: 97.0%
# Testing accuracy: 100.0%

# %%
# predicting and analyzing body fat percentages
y_pred = super_model.predict(X_test)
print(np.sort(y_pred))
print("The average predicted body fat percentage is: {}%".format(np.mean(y_pred).round(2)))
# Out:
# [ 6.15240689  7.44124846  8.88909793  8.90557338  9.20425632  9.45990455
#  10.98283682 11.10669113 11.18730394 11.59629806 11.66263419 11.93908916
#  12.255045   12.26225446 12.85509299 13.56980441 13.72996517 13.91206392
#  14.98398386 15.46537898 16.52396876 16.76617047 16.92636129 17.91096641
#  19.20218845 20.13400825 20.46894866 21.18920825 21.25554349 22.03703087
#  23.14601338 24.45037088 24.57684693 24.82816054 25.08543446 25.38054045
#  25.94585329 26.53379345 26.76012365 26.76835733 26.81014478 27.69547181
#  27.77106581 28.03773179 28.04938378 29.25250819 30.34637625 31.57551632
#  31.58251614 35.37788874 37.25326919]
# The average predicted body fat percentage is: 19.75%

# %% [markdown]
# ## Evaluation Stage

# %%
# importing the evaluation tools
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import precision_score
import math

# %%
# evaluating the model based on the testing set
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mean_squared_error(y_test, y_pred))

# %%
# printing the evaluation metrics
print("R2 score:", r2)
print('Mean squared error:', mse)
print("Root mean squared error:", rmse)

print("Model accuracy: {}%".format(round(r2, 2)*100))
# Out:
# R2 score: 0.9961769743312101
# Mean squared error: 0.2540615592918317
# Root mean squared error: 0.5040451956837122
# Model accuracy: 100.0%

# %%
# # Serializing the model and saving it
# import joblib
# joblib.dump(super_model, 'modelX.joblib')
# print("ModelX Saved Successfully")

# %%
# import pickle

# # save the iris classification model as a pickle file
# model_pkl_file = "modelX.pkl"  

# with open(model_pkl_file, 'wb') as file:  
#     pickle.dump(super_model, file)
# print("ModelX Saved Successfully as a Pickle File")
