# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datasets

# %%
data = pd.read_csv('bodyfat.csv')

# %%
data.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.4   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
data.shape
# Out:
# (252, 15)

# %%
data.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.151190   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368417   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# std      8.430476   10.783077    7.164058    5.249952    2.411805    1.694893
# min     79.300000   69.400000   85.000000   47.200000   33.000000   19.100000
# 25%     94.350000   84.575000   95.500000   56.000000   36.975000   22.000000
# 50%     99.650000   90.950000   99.300000   59.000000   38.500000   22.800000
# 75%    105.375000   99.325000  103.525000   62.350000   39.925000   24.000000
# max    136.200000  148.100000  147.700000   87.300000   49.100000   33.900000
#
#            Biceps     Forearm       Wrist
# count  252.000000  252.000000  252.000000
# mean    32.273413   28.663889   18.229762
# std      3.021274    2.020691    0.933585
# min     24.800000   21.000000   15.800000
# 25%     30.200000   27.300000   17.600000
# 50%     32.050000   28.700000   18.300000
# 75%     34.325000   30.000000   18.800000
# max     45.000000   34.900000   21.400000

# %%
data.dropna()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.4   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
data.drop_duplicates()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.4   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %% [markdown]
# I'm going to be splitting the dataset into features and labels. The features (X) variable consists of the physical features i'm using to make predictions and the labels variable is what i'm trying to predict (Y). I'm not really good with the iloc() function i think it would've done this easier but regardless, i'm still gonna do it my way

# %%
# Features = Independent variable
# Labels = Dependent variable
features = data[['Density','Weight','Neck','Chest','Abdomen','Hip','Thigh','Knee','Ankle','Biceps','Forearm','Wrist']]
labels = data["BodyFat"]

# %% [markdown]
# Visualizing the Features

# %%
features.head()
# Out:
#    Density  Weight  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  Biceps  \
# 0   1.0708  154.25  36.2   93.1     85.2   94.5   59.0  37.3   21.9    32.0
# 1   1.0853  173.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4    30.5
# 2   1.0414  154.00  34.0   95.8     87.9   99.2   59.6  38.9   24.0    28.8
# 3   1.0751  184.75  37.4  101.8     86.4  101.2   60.1  37.3   22.8    32.4
# 4   1.0340  184.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0    32.2
#
#    Forearm  Wrist
# 0     27.4   17.1
# 1     28.9   18.2
# 2     25.2   16.6
# 3     29.4   18.2
# 4     27.7   17.7

# %%
features.shape
# Out:
# (252, 12)

# %%
features.describe()
# Out:
#           Density      Weight        Neck       Chest     Abdomen         Hip  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574  178.924405   37.992063  100.824206   92.555952   99.904762
# std      0.019031   29.389160    2.430913    8.430476   10.783077    7.164058
# min      0.995000  118.500000   31.100000   79.300000   69.400000   85.000000
# 25%      1.041400  159.000000   36.400000   94.350000   84.575000   95.500000
# 50%      1.054900  176.500000   38.000000   99.650000   90.950000   99.300000
# 75%      1.070400  197.000000   39.425000  105.375000   99.325000  103.525000
# max      1.108900  363.150000   51.200000  136.200000  148.100000  147.700000
#
#             Thigh        Knee       Ankle      Biceps     Forearm       Wrist
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    59.405952   38.590476   23.102381   32.273413   28.663889   18.229762
# std      5.249952    2.411805    1.694893    3.021274    2.020691    0.933585
# min     47.200000   33.000000   19.100000   24.800000   21.000000   15.800000
# 25%     56.000000   36.975000   22.000000   30.200000   27.300000   17.600000
# 50%     59.000000   38.500000   22.800000   32.050000   28.700000   18.300000
# 75%     62.350000   39.925000   24.000000   34.325000   30.000000   18.800000
# max     87.300000   49.100000   33.900000   45.000000   34.900000   21.400000

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   Weight   252 non-null    float64
#  2   Neck     252 non-null    float64
#  3   Chest    252 non-null    float64
#  4   Abdomen  252 non-null    float64
#  5   Hip      252 non-null    float64
#  6   Thigh    252 non-null    float64
#  7   Knee     252 non-null    float64
#  8   Ankle    252 non-null    float64
#  9   Biceps   252 non-null    float64
#  10  Forearm  252 non-null    float64
#  11  Wrist    252 non-null    float64
# dtypes: float64(12)
# memory usage: 23.8 KB

# %%
features.dropna()
# Out:
#      Density  Weight  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  Biceps  \
# 0     1.0708  154.25  36.2   93.1     85.2   94.5   59.0  37.3   21.9    32.0
# 1     1.0853  173.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4    30.5
# 2     1.0414  154.00  34.0   95.8     87.9   99.2   59.6  38.9   24.0    28.8
# 3     1.0751  184.75  37.4  101.8     86.4  101.2   60.1  37.3   22.8    32.4
# 4     1.0340  184.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0    32.2
# ..       ...     ...   ...    ...      ...    ...    ...   ...    ...     ...
# 247   1.0736  134.25  34.9   89.2     83.6   88.8   49.6  34.8   21.5    25.6
# 248   1.0236  201.00  40.9  108.5    105.0  104.5   59.6  40.8   23.2    35.2
# 249   1.0328  186.75  38.9  111.1    111.5  101.7   60.3  37.3   21.5    31.3
# 250   1.0399  190.75  38.9  108.3    101.3   97.8   56.0  41.6   22.7    30.5
# 251   1.0271  207.50  40.8  112.4    108.5  107.1   59.3  42.2   24.6    33.7
#
#      Forearm  Wrist
# 0       27.4   17.1
# 1       28.9   18.2
# 2       25.2   16.6
# 3       29.4   18.2
# 4       27.7   17.7
# ..       ...    ...
# 247     25.7   18.5
# 248     28.6   20.1
# 249     27.2   18.0
# 250     29.4   19.8
# 251     30.0   20.9
#
# [252 rows x 12 columns]

# %%
features.drop_duplicates()
# Out:
#      Density  Weight  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  Biceps  \
# 0     1.0708  154.25  36.2   93.1     85.2   94.5   59.0  37.3   21.9    32.0
# 1     1.0853  173.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4    30.5
# 2     1.0414  154.00  34.0   95.8     87.9   99.2   59.6  38.9   24.0    28.8
# 3     1.0751  184.75  37.4  101.8     86.4  101.2   60.1  37.3   22.8    32.4
# 4     1.0340  184.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0    32.2
# ..       ...     ...   ...    ...      ...    ...    ...   ...    ...     ...
# 247   1.0736  134.25  34.9   89.2     83.6   88.8   49.6  34.8   21.5    25.6
# 248   1.0236  201.00  40.9  108.5    105.0  104.5   59.6  40.8   23.2    35.2
# 249   1.0328  186.75  38.9  111.1    111.5  101.7   60.3  37.3   21.5    31.3
# 250   1.0399  190.75  38.9  108.3    101.3   97.8   56.0  41.6   22.7    30.5
# 251   1.0271  207.50  40.8  112.4    108.5  107.1   59.3  42.2   24.6    33.7
#
#      Forearm  Wrist
# 0       27.4   17.1
# 1       28.9   18.2
# 2       25.2   16.6
# 3       29.4   18.2
# 4       27.7   17.7
# ..       ...    ...
# 247     25.7   18.5
# 248     28.6   20.1
# 249     27.2   18.0
# 250     29.4   19.8
# 251     30.0   20.9
#
# [252 rows x 12 columns]

# %%
features.isnull()
# Out:
#      Density  Weight   Neck  Chest  Abdomen    Hip  Thigh   Knee  Ankle  \
# 0      False   False  False  False    False  False  False  False  False
# 1      False   False  False  False    False  False  False  False  False
# 2      False   False  False  False    False  False  False  False  False
# 3      False   False  False  False    False  False  False  False  False
# 4      False   False  False  False    False  False  False  False  False
# ..       ...     ...    ...    ...      ...    ...    ...    ...    ...
# 247    False   False  False  False    False  False  False  False  False
# 248    False   False  False  False    False  False  False  False  False
# 249    False   False  False  False    False  False  False  False  False
# 250    False   False  False  False    False  False  False  False  False
# 251    False   False  False  False    False  False  False  False  False
#
#      Biceps  Forearm  Wrist
# 0     False    False  False
# 1     False    False  False
# 2     False    False  False
# 3     False    False  False
# 4     False    False  False
# ..      ...      ...    ...
# 247   False    False  False
# 248   False    False  False
# 249   False    False  False
# 250   False    False  False
# 251   False    False  False
#
# [252 rows x 12 columns]

# %%
sns.histplot(features,kde=False,bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
#represents the correlation of data in the columns using a heatmap
sns.heatmap(features.corr())
# Out:
# <Axes: >

# %%
#plotting the distribution of the numerical features with a histogram
features.hist(figsize=(15, 8), bins=50, xlabelsize=8, ylabelsize=5);

# %%
X = features
y = labels

# %% [markdown]
# ## Training Stage

# %%
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
# splitting the data into training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
# feature standardization
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# initializing and training the Linear Regression Algorithm to fit my Model
super_model = LinearRegression()
super_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#displaying training and testing accuracy
print("Training accuracy: {}%".format(round(super_model.score(X_train, y_train), 2)*100))
print("Testing accuracy: {}%".format(round(super_model.score(X_test, y_test), 2)*100))
# Out:
# Training accuracy: 97.0%
# Testing accuracy: 99.0%

# %%
# predicting and analyzing body fat percentages
y_pred = super_model.predict(X_test)
print(np.sort(y_pred))
print("The average predicted body fat percentage is: {}%".format(np.mean(y_pred).round(2)))
# Out:
# [ 3.55471176  4.03025451  5.62020853  6.31020775  6.81402819  7.45748718
#   9.26035401 10.11691128 10.60200063 10.8033035  11.49700722 11.50535206
#  11.5531332  11.72320282 11.94802818 12.1815019  12.26998363 12.29761339
#  12.82384757 13.18518554 13.18995702 13.45572066 13.51053278 13.55121946
#  13.56171293 13.7875466  14.06786278 14.09061824 14.40315668 15.13907309
#  15.38330689 15.40199321 16.10394354 16.74575931 17.18394142 17.38079155
#  17.50777292 18.11383754 19.12480321 19.2675475  19.4035108  19.44893088
#  19.54894924 19.67110949 20.54007813 20.56448587 20.70375567 20.76861399
#  20.81653997 21.02059602 21.18169782 21.35105509 21.68840607 21.72992141
#  21.89592468 22.24216221 22.57460981 23.09096136 23.36424274 23.93030516
#  24.54983967 24.58165364 24.70182306 24.74890532 25.1207783  26.25267283
#  26.74916447 27.71978954 27.88572247 28.06875833 28.9052588  29.95486454
#  30.29893914 30.88071287 35.16314499 37.30721946]
# The average predicted body fat percentage is: 18.22%

# %% [markdown]
# ## Evaluation Stage

# %%
# importing the evaluation tools
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import precision_score
import math

# %%
# evaluating the model based on the testing set
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mean_squared_error(y_test, y_pred))

# %%
# printing the evaluation metrics
print("R2 score:", r2)
print('Mean squared error:', mse)
print("Root mean squared error:", rmse)

print("Model accuracy: {}%".format(round(r2, 2)*100))
# Out:
# R2 score: 0.9888074479672309
# Mean squared error: 0.5793467235213986
# Root mean squared error: 0.7611482927271128
# Model accuracy: 99.0%

# %%
# # Serializing the model and saving it
# import joblib
# joblib.dump(super_model, 'modelX.joblib')
# print("ModelX Saved Successfully")

# %%
import pickle

# save the iris classification model as a pickle file
model_pkl_file = "modelX.pkl"  

with open(model_pkl_file, 'wb') as file:  
    pickle.dump(super_model, file)
print("ModelX Saved Successfully as a Pickle File")
# Out:
# ModelX Saved Successfully as a Pickle File
