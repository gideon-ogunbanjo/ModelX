# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
import datasets

# %% [markdown]
# # Reading the Data

# %%
data = pd.read_csv('Measurements.csv')

# %%
data.head()
# Out:
#    Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   1.0708     12.4   23  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist  Body_mass_Index
# 0    32.0     27.4   17.1        23.626779
# 1    30.5     28.9   18.2        23.334338
# 2    28.8     25.2   16.6        24.668737
# 3    32.4     29.4   18.2        24.883227
# 4    32.2     27.7   17.7        25.517358

# %%
data.shape
# Out:
# (252, 14)

# %%
data.describe()
# Out:
#           Density     BodyFat         Age        Neck       Chest     Abdomen  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.151190   44.884921   37.992063  100.824206   92.555952
# std      0.019031    8.368417   12.602040    2.430913    8.430476   10.783077
# min      0.995000    0.000000   22.000000   31.100000   79.300000   69.400000
# 25%      1.041400   12.475000   35.750000   36.400000   94.350000   84.575000
# 50%      1.054900   19.200000   43.000000   38.000000   99.650000   90.950000
# 75%      1.070400   25.300000   54.000000   39.425000  105.375000   99.325000
# max      1.108900   47.500000   81.000000   51.200000  136.200000  148.100000
#
#               Hip       Thigh        Knee       Ankle      Biceps     Forearm  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    99.904762   59.405952   38.590476   23.102381   32.273413   28.663889
# ...

# %%
data.dropna()
# Out:
#      Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0     1.0708     12.4   23  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1     1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2     1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3     1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4     1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2  42.2   24.0
# ..       ...      ...  ...   ...    ...      ...    ...    ...   ...    ...
# 247   1.0736     11.0   70  34.9   89.2     83.6   88.8   49.6  34.8   21.5
# 248   1.0236     33.6   72  40.9  108.5    105.0  104.5   59.6  40.8   23.2
# 249   1.0328     29.3   72  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 250   1.0399     26.0   72  38.9  108.3    101.3   97.8   56.0  41.6   22.7
# 251   1.0271     31.9   74  40.8  112.4    108.5  107.1   59.3  42.2   24.6
#
#      Biceps  Forearm  Wrist  Body_mass_Index
# ...

# %%
data.drop_duplicates()
# Out:
#      Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0     1.0708     12.4   23  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1     1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2     1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3     1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4     1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2  42.2   24.0
# ..       ...      ...  ...   ...    ...      ...    ...    ...   ...    ...
# 247   1.0736     11.0   70  34.9   89.2     83.6   88.8   49.6  34.8   21.5
# 248   1.0236     33.6   72  40.9  108.5    105.0  104.5   59.6  40.8   23.2
# 249   1.0328     29.3   72  38.9  111.1    111.5  101.7   60.3  37.3   21.5
# 250   1.0399     26.0   72  38.9  108.3    101.3   97.8   56.0  41.6   22.7
# 251   1.0271     31.9   74  40.8  112.4    108.5  107.1   59.3  42.2   24.6
#
#      Biceps  Forearm  Wrist  Body_mass_Index
# ...

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# I need the 'Weight' and the 'Height' columns to make predictions. However, Weight is in pounds (lbs), and Height is in Inches (In). I'm going to convert the "Weight" column from pounds to kilograms by multiplying it by the conversion factor 0.453592. Similarly, i will also be converting the "Height" column from inches to meters by multiplying it by 0.0254. Then, i will calculate the Body Mass Index (BMI) by dividing the weight in kilograms by the square of the height in meters.

# %%
# data['Weight_kg'] = data['Weight'] * 0.453592  # 1 pound = 0.453592 kg
# data['Height_m'] = data['Height'] * 0.0254  # 1 inch = 0.0254 meters

# # Calculate BMI
# data['Body_mass_Index'] = data['Weight_kg'] / (data['Height_m'] ** 2)

# # Print the updated DataFrame with the BMI column
# print(data)

# %% [markdown]
# I'm going to be splitting the dataset into features and labels. The features (X) variable consists of the physical features i'm using to make predictions and the labels variable is what i'm trying to predict (Y). I'm not really good with the iloc() function i think it would've done this easier but regardless, i'm still gonna do it my way

# %%
data.head()
# Out:
#    Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   1.0708     12.4   23  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist  Body_mass_Index
# 0    32.0     27.4   17.1        23.626779
# 1    30.5     28.9   18.2        23.334338
# 2    28.8     25.2   16.6        24.668737
# 3    32.4     29.4   18.2        24.883227
# 4    32.2     27.7   17.7        25.517358

# %%
# # dropping the old 'height' and 'weight'coulmn alongside the modified 'Weight_kg' and 'Height_m' column from the dataset
# data.drop(['Height', 'Weight', 'Weight_kg', 'Height_m'], axis=1, inplace=True)

# %%
# data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# # saving the dataframe
# data.to_csv('Measurementss.csv')

# %%
data.head()
# Out:
#    Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   1.0708     12.4   23  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist  Body_mass_Index
# 0    32.0     27.4   17.1        23.626779
# 1    30.5     28.9   18.2        23.334338
# 2    28.8     25.2   16.6        24.668737
# 3    32.4     29.4   18.2        24.883227
# 4    32.2     27.7   17.7        25.517358

# %%
data.head()
# Out:
#    Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   1.0708     12.4   23  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist  Body_mass_Index
# 0    32.0     27.4   17.1        23.626779
# 1    30.5     28.9   18.2        23.334338
# 2    28.8     25.2   16.6        24.668737
# 3    32.4     29.4   18.2        24.883227
# 4    32.2     27.7   17.7        25.517358

# %%
data.shape
# Out:
# (252, 14)

# %%
# Features = Independent variable
# Labels = Dependent variable
features = data[['Density','Body_mass_Index', 'Neck','Chest','Abdomen','Hip','Thigh','Knee','Ankle','Biceps','Forearm','Wrist']]
labels = data["BodyFat"]

# %% [markdown]
# Visualizing the Features

# %%
features.head()
# Out:
#    Density  Body_mass_Index  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   1.0708        23.626779  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   1.0853        23.334338  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   1.0414        24.668737  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   1.0751        24.883227  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   1.0340        25.517358  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist
# 0    32.0     27.4   17.1
# 1    30.5     28.9   18.2
# 2    28.8     25.2   16.6
# 3    32.4     29.4   18.2
# 4    32.2     27.7   17.7

# %%
features.shape
# Out:
# (252, 12)

# %%
features.describe()
# Out:
#           Density  Body_mass_Index        Neck       Chest     Abdomen  \
# count  252.000000       252.000000  252.000000  252.000000  252.000000
# mean     1.055574        25.942199   37.992063  100.824206   92.555952
# std      0.019031         9.558451    2.430913    8.430476   10.783077
# min      0.995000        18.017664   31.100000   79.300000   69.400000
# 25%      1.041400        23.035661   36.400000   94.350000   84.575000
# 50%      1.054900        25.094288   38.000000   99.650000   90.950000
# 75%      1.070400        27.334547   39.425000  105.375000   99.325000
# max      1.108900       165.618094   51.200000  136.200000  148.100000
#
#               Hip       Thigh        Knee       Ankle      Biceps     Forearm  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    99.904762   59.405952   38.590476   23.102381   32.273413   28.663889
# std      7.164058    5.249952    2.411805    1.694893    3.021274    2.020691
# ...

# %%
features.info
# Out:
# <bound method DataFrame.info of      Density  Body_mass_Index  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     1.0708        23.626779  36.2   93.1     85.2   94.5   59.0  37.3
# 1     1.0853        23.334338  38.5   93.6     83.0   98.7   58.7  37.3
# 2     1.0414        24.668737  34.0   95.8     87.9   99.2   59.6  38.9
# 3     1.0751        24.883227  37.4  101.8     86.4  101.2   60.1  37.3
# 4     1.0340        25.517358  34.4   97.3    100.0  101.9   63.2  42.2
# ..       ...              ...   ...    ...      ...    ...    ...   ...
# 247   1.0736        21.026290  34.9   89.2     83.6   88.8   49.6  34.8
# 248   1.0236        29.047288  40.9  108.5    105.0  104.5   59.6  40.8
# 249   1.0328        30.141905  38.9  111.1    111.5  101.7   60.3  37.3
# 250   1.0399        26.982629  38.9  108.3    101.3   97.8   56.0  41.6
# 251   1.0271        29.772820  40.8  112.4    108.5  107.1   59.3  42.2
#
#      Ankle  Biceps  Forearm  Wrist
# 0     21.9    32.0     27.4   17.1
# ...

# %%
features.dropna()
# Out:
#      Density  Body_mass_Index  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     1.0708        23.626779  36.2   93.1     85.2   94.5   59.0  37.3
# 1     1.0853        23.334338  38.5   93.6     83.0   98.7   58.7  37.3
# 2     1.0414        24.668737  34.0   95.8     87.9   99.2   59.6  38.9
# 3     1.0751        24.883227  37.4  101.8     86.4  101.2   60.1  37.3
# 4     1.0340        25.517358  34.4   97.3    100.0  101.9   63.2  42.2
# ..       ...              ...   ...    ...      ...    ...    ...   ...
# 247   1.0736        21.026290  34.9   89.2     83.6   88.8   49.6  34.8
# 248   1.0236        29.047288  40.9  108.5    105.0  104.5   59.6  40.8
# 249   1.0328        30.141905  38.9  111.1    111.5  101.7   60.3  37.3
# 250   1.0399        26.982629  38.9  108.3    101.3   97.8   56.0  41.6
# 251   1.0271        29.772820  40.8  112.4    108.5  107.1   59.3  42.2
#
#      Ankle  Biceps  Forearm  Wrist
# 0     21.9    32.0     27.4   17.1
# ...

# %%
features.drop_duplicates()
# Out:
#      Density  Body_mass_Index  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     1.0708        23.626779  36.2   93.1     85.2   94.5   59.0  37.3
# 1     1.0853        23.334338  38.5   93.6     83.0   98.7   58.7  37.3
# 2     1.0414        24.668737  34.0   95.8     87.9   99.2   59.6  38.9
# 3     1.0751        24.883227  37.4  101.8     86.4  101.2   60.1  37.3
# 4     1.0340        25.517358  34.4   97.3    100.0  101.9   63.2  42.2
# ..       ...              ...   ...    ...      ...    ...    ...   ...
# 247   1.0736        21.026290  34.9   89.2     83.6   88.8   49.6  34.8
# 248   1.0236        29.047288  40.9  108.5    105.0  104.5   59.6  40.8
# 249   1.0328        30.141905  38.9  111.1    111.5  101.7   60.3  37.3
# 250   1.0399        26.982629  38.9  108.3    101.3   97.8   56.0  41.6
# 251   1.0271        29.772820  40.8  112.4    108.5  107.1   59.3  42.2
#
#      Ankle  Biceps  Forearm  Wrist
# 0     21.9    32.0     27.4   17.1
# ...

# %%
features.isnull()
# Out:
#      Density  Body_mass_Index   Neck  Chest  Abdomen    Hip  Thigh   Knee  \
# 0      False            False  False  False    False  False  False  False
# 1      False            False  False  False    False  False  False  False
# 2      False            False  False  False    False  False  False  False
# 3      False            False  False  False    False  False  False  False
# 4      False            False  False  False    False  False  False  False
# ..       ...              ...    ...    ...      ...    ...    ...    ...
# 247    False            False  False  False    False  False  False  False
# 248    False            False  False  False    False  False  False  False
# 249    False            False  False  False    False  False  False  False
# 250    False            False  False  False    False  False  False  False
# 251    False            False  False  False    False  False  False  False
#
#      Ankle  Biceps  Forearm  Wrist
# 0    False   False    False  False
# ...

# %% [markdown]
# ## Data Visualization

# %%
sns.histplot(features,kde=False,bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
#represents the correlation of data in the columns using a heatmap
sns.heatmap(features.corr())
# Out:
# <Axes: >

# %%
#plotting the distribution of the numerical features with a histogram
features.hist(figsize=(15, 8), bins=50, xlabelsize=8, ylabelsize=5);

# %%
chart = data.boxplot(column = ['Body_mass_Index'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 0)
plt.title('The Factor of Body Mass Index', fontsize = 15, color = 'maroon', pad = 12)
plt.xlabel('Factors')
plt.ylabel('Count')
plt.show()

# %%
# #profile report of the dataset
# pandas_profiling.ProfileReport(data)

# %%
X = features #target variable
y = labels #predicted variable

# %% [markdown]
# ## Training Stage

# %%
from sklearn.linear_model import Ridge , Lasso , ElasticNet , LinearRegression

# %%
# splitting the data into training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state= 42)

# %%
# feature standardization
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Linear Regression

# %%
# initializing and training the Linear Regression Algorithm to fit my Model
super_model = LinearRegression()
super_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#displaying training and testing accuracy
print("Training accuracy: {}%".format(round(super_model.score(X_train, y_train), 2)*100))
print("Testing accuracy: {}%".format(round(super_model.score(X_test, y_test), 2)*100))
# Out:
# Training accuracy: 97.0%
# Testing accuracy: 99.0%

# %% [markdown]
# Ridge Regression

# %%
# model = Ridge()
# model.fit(X_train , y_train)
# print("Training accuracy: {}%".format(round(super_model.score(X_train, y_train), 2)*100))
# print("Testing accuracy: {}%".format(round(super_model.score(X_test, y_test), 2)*100))

# %% [markdown]
# Lasso Regression

# %%
# model = Lasso()
# model.fit(X_train , y_train)
# print("Training accuracy: {}%".format(round(super_model.score(X_train, y_train), 2)*100))
# print("Testing accuracy: {}%".format(round(super_model.score(X_test, y_test), 2)*100))

# %%
# # Elastic 

# # lambda_1*L1 + lambda_2*L2 
# # alpha = lambda_1 + lambda_2 , l1_ratio = lambda_1/(lambda_1 + lambda_2)

# model = ElasticNet()
# model.fit(X_train , y_train)
# print("Training accuracy: {}%".format(round(super_model.score(X_train, y_train), 2)*100))
# print("Testing accuracy: {}%".format(round(super_model.score(X_test, y_test), 2)*100))

# %%
# predicting and analyzing body fat percentages
y_pred = super_model.predict(X_test)

# %% [markdown]
# ## Evaluation Stage

# %%
# importing the evaluation tools
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import precision_score
import math

# %%
# evaluating the model based on the testing set
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mean_squared_error(y_test, y_pred))

# %%
# printing the evaluation metrics
print("R2 score:", r2)
print('Mean squared error:', mse)
print("Root mean squared error:", rmse)

print("Model accuracy: {}%".format(round(r2, 2)*100))
# Out:
# R2 score: 0.9890226891216881
# Mean squared error: 0.568205452322777
# Root mean squared error: 0.7537940383969464
# Model accuracy: 99.0%

# %%
# import joblib
# joblib.dump(super_model, 'modelX.joblib')
# print("ModelX Saved Successfully with Joblib")
# Out:
# ModelX Saved Successfully with Joblib

# %%
# import pickle

# # save the iris classification model as a pickle file
# model_pkl_file = "modelx.pkl"  

# with open(model_pkl_file, 'wb') as file:  
#     pickle.dump(super_model, file)
# print("ModelX Saved Successfully as a Pickle File")
# Out:
# ModelX Saved Successfully as a Pickle File
